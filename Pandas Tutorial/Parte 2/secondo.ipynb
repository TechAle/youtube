# %% [markdown]
# ## Librerie

# %%
import pandas as pd

# %% [markdown]
# ## Caricamento

# %%
## Da file
studenti = pd.read_csv("studenti.csv")
studenti_nuovi = pd.read_pickle("studenti_nuovi.pkl")
## Inizializzazione
nuovo = {
    "Nome" : ["Alessandro"],
    "Cognome" : ["Ciao"],
    "Codice" : [100],
    "Classe" : ["1AIN"]
}
pd.DataFrame(nuovo)
# Out:
#          Nome Cognome  Codice Classe
# 0  Alessandro    Ciao     100   1AIN

# %% [markdown]
# ## Analizziamo

# %%
# studenti
## Modifico la troncatura
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)
studenti
### Visionamento generale
## Dimensioni
# studenti.shape
## Inizio - fine
# studenti.head(2)
# studenti.tail(2)
# Out:
#             Nome      Cognome   Codice Classe                    Voti  Promosso  Comportamento
# 0           Inga       Adolfo  11981.0   1AIN         [3 8 6 9 3 7 7]       1.0            8.0
# 1           Leon        Bardo  11982.0   1AIN         [8 6 7 6 3 8 3]       0.0           10.0
# 2           Orso   Elisabetta  11983.0   1AIN         [8 4 8 7 9 5 7]       1.0            9.0
# 3          Megan   Guendalina  11984.0   1AIN  [ 4 10  5  7 10  7  4]       1.0           10.0
# 4            Pio      Eugenio  11985.0   1AIN         [5 9 6 4 7 9 6]       1.0            9.0
# 5       Raimonda     Giuliana  11986.0   1AIN         [6 9 7 9 5 9 5]       1.0            9.0
# 6         Tullia         Fara  11987.0   1AIN         [5 6 4 7 3 3 3]       0.0           10.0
# 7         Silvia     Gardenia  11988.0   1BEN  [ 9  9  8  6  3 10  4]       1.0            8.0
# 8        Simeone      Assunta  11989.0   1BEN  [ 9  6  5  8  4 10  6]       1.0            9.0
# ...

# %% [markdown]
# ## Indexing

# %%
## Guardo tutte le colonne
studenti.columns
## Guardo la colonna nomi
studenti["Nome"]
## Un altro modo per guardare una colonna
studenti.Nome
## Guardare nome e cognomi
studenti[["Nome", "Cognome"]]
# Out:
#             Nome      Cognome
# 0           Inga       Adolfo
# 1           Leon        Bardo
# 2           Orso   Elisabetta
# 3          Megan   Guendalina
# 4            Pio      Eugenio
# 5       Raimonda     Giuliana
# 6         Tullia         Fara
# 7         Silvia     Gardenia
# 8        Simeone      Assunta
# 9           Nara     Graziano
# 10           Ada      Doriana
# 11         Maria       Lilith
# 12         Alida        Altea
# 13       Jessica      Ignazio
# 14       Leonida        Aimeè
# 15       Ignazio        Ermes
# 16           Tia       Egidio
# 17      Lancelot      Edgardo
# 18       Satinka        Bruna
# 19        Altair         Jael
# 20     Anastasia          Ebe
# 21        Cedric        Bjorn
# 22        Cesara         Vida
# 23       Leonida      Madonna
# 24           Era     Filomena
# 25          Ford       Rowena
# 26        Enrica      Letizia
# 27          Dina        Medea
# 28        Evania       Melvin
# 29       Malvina      Marilyn
# ...

# %%
## Prendo un dataframe usando l'index
studenti.iloc[0]
studenti.iloc[0,0]
studenti.iloc[[0,1], [0,1,2]]
# Out:
#    Nome Cognome   Codice
# 0  Inga  Adolfo  11981.0
# 1  Leon   Bardo  11982.0

# %%
## Utilizzo senza usare l'index
studenti.loc[0, "Nome"]
studenti.loc[[0,1], ["Nome", "Cognome"]]
studenti.loc[0:2, "Nome" : "Codice"]
# Out:
#    Nome     Cognome   Codice
# 0  Inga      Adolfo  11981.0
# 1  Leon       Bardo  11982.0
# 2  Orso  Elisabetta  11983.0

# %%
## Modifico Codice
## Rinomino assegnando
# studenti.columns = ["Nome", "Cognome", "Matricola", "Classe", "Voti", "Promosso"]
## Rinomino usando rename
studenti.rename(columns={"Codice" : "Matricola"}, inplace = True)
## Rendo tutto minuscolo
studenti.columns = [x.lower() for x in studenti.columns]
# studenti

# %%
## Setto il codice come index
# studenti = studenti.set_index("Codice", inplace = True)
studenti.set_index("matricola", inplace = True)
studenti.loc[11981]
# Out:
# nome                        Inga
# cognome                   Adolfo
# classe                      1AIN
# voti             [3 8 6 9 3 7 7]
# promosso                       1
# comportamento                  8
# Name: 11981.0, dtype: object

# %% [markdown]
# ## Divisione promossi e bocciati

# %%
## Prendo tutti i bocciati
filt = (studenti["promosso"] == 0)

# %%
## Prendo la classe e i voti dei promossi
studenti.loc[~filt, ["classe", "voti"]]
## Conto il numero di bocciati
studenti["promosso"].value_counts()[0]
# Out:
# 70

# %% [markdown]
# ## Altri dati

# %%
# studenti_nuovi
## Elimino la prima riga
# studenti_nuovi.drop(0)
## Modifico la seconda riga usando loc
# studenti_nuovi.loc[1] = ["Angelica", "Rossi", 12300, "1IEN"]
## Modifico un valore della seconda riga usando at
# studenti_nuovi.at[2, "Classe"] = "1IEN"
## Modifico un valore usando iat
# studenti_nuovi.iat[0, 0] = "Marco"

# %% [markdown]
# ## Unione colonne

# %%
studenti["nome_completo"] = studenti["nome"] + ' ' + studenti["cognome"]
studenti.drop(columns = ["nome", "cognome"], inplace = True)

# %%
studenti_nuovi.head()
# Out:
#         Nome  Cognome   Codice Classe
# 0    Talitha  Daniela  12224.0   1AIN
# 1       Lara   Annika  12225.0   1AIN
# 2      Doris     Edda  12226.0   1AIN
# 3  Alfonsina  Alberto  12227.0   1AIN
# 4     Giotto  Quinzio  12228.0   1AIN

# %%
## Da 1 colonna a 2 colonne
# studenti[["nome", "cognome"]] = studenti["nome_completo"].str.split(' ', expand = True)

# %% [markdown]
# ## Media

# %%
## Prendo la lunghezza di tutti i nomi
#studenti["nome_completo"].apply(len)
## Prendo quanti oggetti abbiamo
#studenti.apply(len)
## Prendo la lunghezza delle colonne
#studenti.apply(len, axis='columns')
## Prendo il valore minimo in ogni colonna
#studenti.apply(pd.Series.min)
## Rendo tutti i nomi minuscoli
#studenti.applymap(lambda x: x.lower() if isinstance(x, str) else x )
## Rendo il comportamento uguale a 9 buono
## Uguale a 10 molto buono e gli altri NaN
#studenti["comportamento"].map({9.0 : "buono", 10.0 : "molto buono"})
## Rendiamo il comportamento uguale a 10 "Eccellenza"
#studenti["comportamento"].replace({10.0 : "Eccellenza"})
## Trasformo la lista (che è stata scritta come stringa) in una lista di interi
voti_int = studenti["voti"].apply(lambda x : pd.Series(list(map(int, x[1:-1].split()))))
## Genero la media
medie = voti_int.mean(axis = "columns").round(2)
## La applico
voti_int["media"] = medie
filt = voti_int["media"] > 7.5
## Contare i valori
# filt.value_counts()
alti = voti_int.loc[filt]
# voti_int = voti_int.loc[~filt]
voti_int.drop(voti_int[filt].index, inplace = True)

# %% [markdown]
# ## Ordinamento

# %%
studenti["media"] = medie

# %%
studenti.sort_values(by = ["media", "comportamento"], ascending = [False, False], inplace = True)
studenti.sort_index(inplace = True)
# studenti

# %% [markdown]
# ## Nuovo anno 1/2

# %%
# studenti_nuovi
## Rendiamo studenti_nuovi compatibile con studenti
## Rinominiamo codice in matricola
studenti_nuovi.rename(columns={"Codice" : "Matricola"}, inplace = True)
## Rendo tutto minuscolo
studenti_nuovi.columns = [x.lower() for x in studenti_nuovi.columns]
## Rendo index matricola
studenti_nuovi.set_index("matricola", inplace = True)
## Unisco nome e cognome
studenti_nuovi["nome_completo"] = studenti_nuovi["nome"] + ' ' + studenti_nuovi["cognome"]
## Tolgo le colonne nome e cognome
studenti_nuovi.drop(columns = ["nome" , "cognome"], inplace = True)

# %%
## Tolgo le quinte
filt = studenti["classe"].str[0] == '5'
## Creo una copia per il punto dopo
copia_studenti = studenti.copy()
studenti.drop(studenti[filt].index, inplace = True)

# %%
## Unisco tutto
studenti_fin = studenti_nuovi.append(studenti)

# %%
studenti_fin
# Out:
#           classe         nome_completo                    voti  promosso  comportamento  media
# matricola
# 12224.0     1AIN       Talitha Daniela                     NaN       NaN            NaN    NaN
# 12225.0     1AIN           Lara Annika                     NaN       NaN            NaN    NaN
# 12226.0     1AIN            Doris Edda                     NaN       NaN            NaN    NaN
# 12227.0     1AIN     Alfonsina Alberto                     NaN       NaN            NaN    NaN
# 12228.0     1AIN        Giotto Quinzio                     NaN       NaN            NaN    NaN
# 12229.0     1AIN        Satinka Carina                     NaN       NaN            NaN    NaN
# 12230.0     1AIN           Sennen Sean                     NaN       NaN            NaN    NaN
# 12231.0     1AIN         Evania Adolfo                     NaN       NaN            NaN    NaN
# 12232.0     1AIN          Nolan Elvira                     NaN       NaN            NaN    NaN
# ...

# %% [markdown]
# ## Fine anno 2/2

# %%
### studenti_nuovi va bene e useremo l'output di sopra
### L'eliminazione delle quinte va bene e useremo l'output di sopra
## Modifichiamo le classi. Se l'alunno è stato promosso
def analisi(classe, promosso):
    intero = int(classe[0])
    if promosso:
        intero += 1
    return "{}{}".format(intero, classe[1:])
copia_studenti["classe"] = copia_studenti.apply(lambda x : analisi(x["classe"], x["promosso"]), axis=1)
## Elimino tutti quelli che sono passati in quinta
filt = copia_studenti["classe"].str[0] == '6'
copia_studenti.drop(copia_studenti[filt].index, inplace = True)
## Ordiniamo per la classe
copia_studenti.sort_values(by = "classe", inplace = True)
## Elimino le colonne eccessive
copia_studenti.drop(columns = ["voti", "comportamento", "media", "promosso"], inplace = True)
copia_studenti = studenti_nuovi.append(copia_studenti)

# %%
copia_studenti
# Out:
#           classe         nome_completo
# matricola
# 12224.0     1AIN       Talitha Daniela
# 12225.0     1AIN           Lara Annika
# 12226.0     1AIN            Doris Edda
# 12227.0     1AIN     Alfonsina Alberto
# 12228.0     1AIN        Giotto Quinzio
# 12229.0     1AIN        Satinka Carina
# 12230.0     1AIN           Sennen Sean
# 12231.0     1AIN         Evania Adolfo
# 12232.0     1AIN          Nolan Elvira
# 12233.0     1BEN         Silvia Severo
# 12234.0     1BEN         Zoe Nicoletta
# 12235.0     1BEN          Marta Graham
# 12236.0     1BEN      Ortensia Rosalia
# 12237.0     1BEN         Filippo Mabel
# 12238.0     1BEN        Prisca Celeste
# 12239.0     1BEN         Alea Ludovica
# 12240.0     1BEN        Fedele Fabiana
# 12241.0     1CIN         Alhena Alvaro
# 12242.0     1CIN       Quirino Dionigi
# 12243.0     1CIN           Palma Carla
# 12244.0     1CIN       Leonida Doriano
# 12245.0     1CIN        Lothar Luciano
# 12246.0     1CIN        Nerina Melissa
# ...

# %% [markdown]
# ## Divisione in classi

# %%
## Raggruppo
classe = studenti.groupby(["classe"])
## Vedere tutte le classi
# studenti["classe"].unique()
for i in studenti["classe"].unique():
    print("{} : {}".format(i, classe.get_group(i)["media"].mean()))
# Out:
# 1AIN : 6.244285714285715
# 1BEN : 7.086
# 1CEN : 6.4275
# 1DIN : 6.531428571428571
# 1EEN : 6.57125
# 1FEN : 6.808888888888889
# 1GIN : 6.484999999999999
# 1HIN : 6.588888888888889
# 1IIN : 6.6775
# 1JIN : 6.43
# 1KEN : 6.32
# 2AEN : 6.515000000000001
# 2BEN : 6.715714285714285
# 2CEN : 5.976666666666667
# 2DEN : 6.358333333333333
# 2EEN : 6.57
# 2FIN : 6.618333333333333
# 2GIN : 6.072
# 2HIN : 6.368571428571428
# 2IEN : 6.143
# 3AEN : 6.387142857142857
# 3BEN : 6.056
# 3CIN : 6.788333333333333
# 3DEN : 6.857142857142857
# 3EIN : 6.028
# 3FIN : 6.371
# 4AEN : 6.903333333333333
# 4BEN : 6.27
# 4CEN : 6.0
